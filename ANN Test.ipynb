# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image


def fetch_dataset(path):
    images = []
    labels = []
    for dir1 in os.listdir(path):
        for file in os.listdir(os.path.join(path,dir1)):
            image_path = os.path.join(path,dir1,file)
            with Image.open(image_path).convert('L') as img:
                arr = np.array(img.getdata()).reshape(256, 256, 1) / 255
                images.append(arr)
                labels.append(dir1)
    return images,labels


test_path = os.path.join("data","val")

test_images,test_labels = fetch_dataset(test_path)


    
print(np.unique(test_labels))
#print(arr.shape, arr[:, :, 0])


fig, axes = plt.subplots(1,4,figsize=(12, 7))
labels_unique = []
j = 0
for i,label in enumerate(test_labels):
    if (label in labels_unique):
        continue
    labels_unique.append(label)
    ax = axes[j]
    ax.imshow(test_images[i])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel("Category " + label)
    print(label)
    j+=1
    
print(labels_unique)



# fig, axes = plt.subplots(1,4,figsize=(12, 7))
# for i,label in enumerate(np.unique(test_labels)):
#     ax = axes[i]
#     idxs = test_labels==label
#     ax.imshow(test_images[idxs])
#     ax.set_xticks([])
#     ax.set_yticks([])
#     ax.set_xlabel("Category " + label)
#     print(label)
# Out:
# ['COVID' 'HEALTHY' 'PNEUMONIA_BAC' 'PNEUMONIA_VIR']
# COVID
# HEALTHY
# PNEUMONIA_BAC
# PNEUMONIA_VIR
# ['COVID', 'HEALTHY', 'PNEUMONIA_BAC', 'PNEUMONIA_VIR']
